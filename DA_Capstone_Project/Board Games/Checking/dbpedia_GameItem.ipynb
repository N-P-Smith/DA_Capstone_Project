# %%
# https://www.kaggle.com/datasets/mshepherd/board-games?select=bgg_Category.csv

# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/dbpedia_GameItem.csv")

df
# Out:
#       bgg_id                       name    year  game_type          designer  \
# 0        NaN  "Glozel est Authentique!"     NaN        NaN               NaN
# 1        NaN                      *Star     NaN        NaN             Ea Ea
# 2        NaN                      .hack     NaN        NaN               NaN
# 3     4550.0     1000 Blank White Cards  1996.0        NaN               NaN
# 4        NaN      100 mexicanos dijeron     NaN        NaN               NaN
# ...      ...                        ...     ...        ...               ...
# 4200     NaN                       Zyll     NaN        NaN               NaN
# 4201     NaN                      ZÈRTZ     NaN        NaN  Kris Burm,크리스 뷔름
# 4202     NaN                 Ætherverse     NaN        NaN               NaN
# 4203     NaN                     Écarté     NaN        NaN               NaN
# 4204     NaN                  Ô ăn quan     NaN        NaN               NaN
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4205 entries, 0 to 4204
# Data columns (total 38 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   bgg_id               156 non-null    float64
#  1   name                 4205 non-null   object
#  2   year                 814 non-null    float64
#  3   game_type            0 non-null      float64
#  4   designer             949 non-null    object
#  5   artist               0 non-null      float64
#  6   publisher            1653 non-null   object
#  7   min_players          1262 non-null   float64
#  8   max_players          0 non-null      float64
#  9   min_players_rec      0 non-null      float64
#  10  max_players_rec      0 non-null      float64
#  11  min_players_best     0 non-null      float64
#  12  max_players_best     0 non-null      float64
#  13  min_age              513 non-null    float64
#  14  min_age_rec          0 non-null      float64
# ...

# %%
df.describe()
# Out:
#               bgg_id         year  game_type  artist  min_players  \
# count     156.000000   814.000000        0.0     0.0  1262.000000
# mean    45839.756410  1957.363636        NaN     NaN     5.040412
# std     67358.332785   261.348731        NaN     NaN    67.218034
# min        74.000000     1.000000        NaN     NaN     1.000000
# 25%      3839.250000  1984.000000        NaN     NaN     2.000000
# 50%     15458.500000  1993.000000        NaN     NaN     2.000000
# 75%     40782.750000  2004.000000        NaN     NaN     2.000000
# max    328680.000000  2022.000000        NaN     NaN  2346.000000
#
#        max_players  min_players_rec  max_players_rec  min_players_best  \
# count          0.0              0.0              0.0               0.0
# mean           NaN              NaN              NaN               NaN
# std            NaN              NaN              NaN               NaN
# min            NaN              NaN              NaN               NaN
# ...
