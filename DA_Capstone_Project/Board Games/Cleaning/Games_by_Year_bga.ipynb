# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data.

df = pd.read_csv("../Data/bga_GameItem.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 124026 entries, 0 to 124025
# Data columns (total 38 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   bgg_id               0 non-null       float64
#  1   name                 124026 non-null  object
#  2   year                 100194 non-null  float64
#  3   game_type            0 non-null       float64
#  4   designer             70088 non-null   object
#  5   artist               41919 non-null   object
#  6   publisher            96154 non-null   object
#  7   min_players          105590 non-null  float64
#  8   max_players          105478 non-null  float64
#  9   min_players_rec      0 non-null       float64
#  10  max_players_rec      0 non-null       float64
#  11  min_players_best     0 non-null       float64
#  12  max_players_best     0 non-null       float64
#  13  min_age              84354 non-null   float64
#  14  min_age_rec          0 non-null       float64
#  15  min_time             86505 non-null   float64
#  16  max_time             86393 non-null   float64
#  17  category             13829 non-null   object
#  18  mechanic             19253 non-null   object
#  19  cooperative          0 non-null       float64
#  20  compilation          0 non-null       float64
#  21  compilation_of       0 non-null       float64
#  22  family               0 non-null       float64
#  23  implementation       0 non-null       float64
#  24  integration          0 non-null       float64
#  25  rank                 0 non-null       float64
#  26  num_votes            123033 non-null  float64
#  27  avg_rating           21247 non-null   float64
#  28  stddev_rating        0 non-null       float64
#  29  bayes_rating         0 non-null       float64
#  30  complexity           0 non-null       float64
#  31  language_dependency  0 non-null       float64
#  32  bga_id               124026 non-null  object
#  33  dbpedia_id           0 non-null       float64
#  34  luding_id            0 non-null       float64
#  35  spielen_id           0 non-null       float64
#  36  wikidata_id          0 non-null       float64
#  37  wikipedia_id         0 non-null       float64
# dtypes: float64(31), object(7)
# memory usage: 36.0+ MB

# %%
# Selecting relevant collumn.

df1 = df["year"].astype('Int64').dropna(axis=0)

df1
# Out:
# 0         2004
# 1         2020
# 2         1996
# 3         2010
# 5         2016
#           ...
# 124021    2008
# 124022    2014
# 124023    2007
# 124024    1979
# 124025    2008
# Name: year, Length: 100194, dtype: Int64

# %%
df1.describe()
# Out:
# count       100194.0
# mean     2001.450596
# std        35.936881
# min            100.0
# 25%           1997.0
# 50%           2009.0
# 75%           2016.0
# max           2024.0
# Name: year, dtype: Float64

# %%
df1.unique()
# Out:
# <IntegerArray>
# [2004, 2020, 1996, 2010, 2016, 2002, 2008, 2011, 2003, 2001,
#  ...
#  1827, 1770, 1778, 1636, 1740, 1430, 1202, 1720,  800,  762]
# Length: 317, dtype: Int64

# %%
plt.figure(figsize=(12,5)) 

sns.histplot(data = df1)

plt.xticks(rotation=90);

# %%
df_sub1000 = df[df["year"] < 1000]

df_sub1000
# Out:
#         bgg_id             name   year  game_type  \
# 8381       NaN         Sugoroku  550.0        NaN
# 8702       NaN         Shatranj  550.0        NaN
# 13753      NaN        Hnefatafl  400.0        NaN
# 20860      NaN       Chaturanga  650.0        NaN
# 27794      NaN            Oware  550.0        NaN
# 43595      NaN             Achi  300.0        NaN
# 49291      NaN  Byzantine Chess  900.0        NaN
# 51976      NaN        T'shu-p'u  220.0        NaN
# 55736      NaN        Ashtapada  350.0        NaN
# 71930      NaN         Parchisi  400.0        NaN
# 74694      NaN            Liubo  700.0        NaN
# 81890      NaN              Mia  600.0        NaN
# 89654      NaN          Fan Tan  600.0        NaN
# 93777      NaN         Yut Nori  500.0        NaN
# 95230      NaN          Petteia  100.0        NaN
# 102449     NaN          Go-Moku  700.0        NaN
# 119463     NaN   Alea evangelii  800.0        NaN
# 120440     NaN          Xiangqi  762.0        NaN
#
#                                   designer  \
# 8381                                   NaN
# 8702                                   NaN
# 13753   id,num_games,score,game,url,images
# 20860   id,num_games,score,game,url,images
# 27794   id,num_games,score,game,url,images
# 43595                                  NaN
# 49291                                  NaN
# 51976                                  NaN
# 55736   id,num_games,score,game,url,images
# 71930   id,num_games,score,game,url,images
# 74694                                  NaN
# 81890                                  NaN
# 89654                                  NaN
# 93777   id,num_games,score,game,url,images
# 95230   id,num_games,score,game,url,images
# 102449  id,num_games,score,game,url,images
# 119463                                 NaN
# 120440                                 NaN
#
#                                                    artist  \
# 8381                                                  NaN
# 8702                                                  NaN
# 13753                          Nathan Morse,Dieter Zander
# 20860                                                 NaN
# 27794                                     Mariela Arratia
# 43595                                                 NaN
# 49291                                                 NaN
# 51976                                                 NaN
# 55736                                                 NaN
# 71930   Rune Andréasson,Kurt Brandes,Silvia Christoph,...
# 74694                                                 NaN
# 81890                                                 NaN
# 89654                                                 NaN
# 93777                                            Kano Kim
# 95230                               Néstor Romeral Andrés
# 102449                                   Manfred Burggraf
# 119463                                                NaN
# 120440                                                NaN
#
#                                       publisher  min_players  max_players  \
# 8381    name,id,url,num_games,score,game,images          2.0          2.0
# 8702                                        NaN          2.0          2.0
# 13753   name,id,url,num_games,score,game,images          2.0          2.0
# 20860   id,name,url,num_games,score,game,images          2.0          4.0
# 27794   name,id,url,num_games,score,game,images          2.0          2.0
# 43595   name,id,url,num_games,score,game,images          2.0          2.0
# 49291   name,id,url,num_games,score,game,images          2.0          2.0
# 51976                                       NaN          4.0          4.0
# 55736                                       NaN          2.0          2.0
# 71930   id,name,url,num_games,score,game,images          2.0          6.0
# 74694                                       NaN          2.0          2.0
# 81890                                       NaN          2.0         12.0
# 89654                                       NaN          3.0          8.0
# 93777   id,name,url,num_games,score,game,images          2.0          8.0
# 95230   name,id,url,num_games,score,game,images          2.0          2.0
# 102449  name,id,url,num_games,score,game,images          2.0          2.0
# 119463  name,id,url,num_games,score,game,images          2.0          2.0
# 120440  name,id,url,num_games,score,game,images          2.0          2.0
#
#         min_players_rec  ...  stddev_rating  bayes_rating  complexity  \
# 8381                NaN  ...            NaN           NaN         NaN
# 8702                NaN  ...            NaN           NaN         NaN
# 13753               NaN  ...            NaN           NaN         NaN
# 20860               NaN  ...            NaN           NaN         NaN
# 27794               NaN  ...            NaN           NaN         NaN
# 43595               NaN  ...            NaN           NaN         NaN
# 49291               NaN  ...            NaN           NaN         NaN
# 51976               NaN  ...            NaN           NaN         NaN
# 55736               NaN  ...            NaN           NaN         NaN
# 71930               NaN  ...            NaN           NaN         NaN
# 74694               NaN  ...            NaN           NaN         NaN
# 81890               NaN  ...            NaN           NaN         NaN
# 89654               NaN  ...            NaN           NaN         NaN
# 93777               NaN  ...            NaN           NaN         NaN
# 95230               NaN  ...            NaN           NaN         NaN
# 102449              NaN  ...            NaN           NaN         NaN
# 119463              NaN  ...            NaN           NaN         NaN
# 120440              NaN  ...            NaN           NaN         NaN
#
#         language_dependency      bga_id  dbpedia_id  luding_id spielen_id  \
# 8381                    NaN  4KLwoCA0Xt         NaN        NaN        NaN
# 8702                    NaN  4Vz0OdCPGa         NaN        NaN        NaN
# 13753                   NaN  74iQBz5vqM         NaN        NaN        NaN
# 20860                   NaN  AYiqU0bC8O         NaN        NaN        NaN
# 27794                   NaN  DQmoqK1CMk         NaN        NaN        NaN
# 43595                   NaN  KQ8CRUCD1o         NaN        NaN        NaN
# 49291                   NaN  NPuoh7Rsom         NaN        NaN        NaN
# 51976                   NaN  Oq3UZ1HLzt         NaN        NaN        NaN
# 55736                   NaN  Qm8HAhgbZP         NaN        NaN        NaN
# 71930                   NaN  Z1TRnABsPZ         NaN        NaN        NaN
# 74694                   NaN  aOy9aeAtD4         NaN        NaN        NaN
# 81890                   NaN  e8aUD2xMCw         NaN        NaN        NaN
# 89654                   NaN  i7Am8ghdw0         NaN        NaN        NaN
# 93777                   NaN  kDYUnNPft9         NaN        NaN        NaN
# 95230                   NaN  kzBLCXYeeA         NaN        NaN        NaN
# 102449                  NaN  oj0996wdlK         NaN        NaN        NaN
# 119463                  NaN  xcfbch7cHC         NaN        NaN        NaN
# 120440                  NaN  y7ZV42RDdA         NaN        NaN        NaN
#
#        wikidata_id  wikipedia_id
# 8381           NaN           NaN
# 8702           NaN           NaN
# 13753          NaN           NaN
# 20860          NaN           NaN
# 27794          NaN           NaN
# 43595          NaN           NaN
# 49291          NaN           NaN
# 51976          NaN           NaN
# 55736          NaN           NaN
# 71930          NaN           NaN
# 74694          NaN           NaN
# 81890          NaN           NaN
# 89654          NaN           NaN
# 93777          NaN           NaN
# 95230          NaN           NaN
# 102449         NaN           NaN
# 119463         NaN           NaN
# 120440         NaN           NaN
#
# [18 rows x 38 columns]

# %%
df2 = df1[df1 > 1900]

df2
# Out:
# 0         2004
# 1         2020
# 2         1996
# 3         2010
# 5         2016
#           ...
# 124021    2008
# 124022    2014
# 124023    2007
# 124024    1979
# 124025    2008
# Name: year, Length: 99165, dtype: Int64

# %%
plt.figure(figsize=(12,5)) 

sns.histplot(data = df2)

plt.xticks(rotation=90);
