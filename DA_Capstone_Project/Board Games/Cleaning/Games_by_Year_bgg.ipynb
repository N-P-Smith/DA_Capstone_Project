# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Loading the data.

df = pd.read_csv("../Data/bgg_GameItem.csv")

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 113904 entries, 0 to 113903
# Data columns (total 38 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   bgg_id               113904 non-null  int64
#  1   name                 113904 non-null  object
#  2   year                 104219 non-null  float64
#  3   game_type            25830 non-null   object
#  4   designer             95653 non-null   object
#  5   artist               47872 non-null   object
#  6   publisher            113852 non-null  object
#  7   min_players          111966 non-null  float64
#  8   max_players          108448 non-null  float64
#  9   min_players_rec      111966 non-null  float64
#  10  max_players_rec      108448 non-null  float64
#  11  min_players_best     111966 non-null  float64
#  12  max_players_best     108448 non-null  float64
#  13  min_age              90641 non-null   float64
#  14  min_age_rec          1126 non-null    float64
#  15  min_time             91342 non-null   float64
#  16  max_time             91342 non-null   float64
#  17  category             111690 non-null  object
#  18  mechanic             97137 non-null   object
#  19  cooperative          6354 non-null    float64
#  20  compilation          915 non-null     float64
#  21  compilation_of       915 non-null     object
#  22  family               79045 non-null   object
#  23  implementation       5865 non-null    object
#  24  integration          4120 non-null    object
#  25  rank                 24479 non-null   float64
#  26  num_votes            86182 non-null   float64
#  27  avg_rating           86182 non-null   float64
#  28  stddev_rating        68497 non-null   float64
#  29  bayes_rating         24934 non-null   float64
#  30  complexity           48290 non-null   float64
#  31  language_dependency  854 non-null     float64
#  32  bga_id               0 non-null       float64
#  33  dbpedia_id           0 non-null       float64
#  34  luding_id            0 non-null       float64
#  35  spielen_id           0 non-null       float64
#  36  wikidata_id          0 non-null       float64
#  37  wikipedia_id         0 non-null       float64
# dtypes: float64(26), int64(1), object(11)
# memory usage: 33.0+ MB

# %%
df
# Out:
#         bgg_id                           name    year game_type  \
# 0            1                     Die Macher  1986.0      5497
# 1            2                   Dragonmaster  1981.0      5497
# 2            3                        Samurai  1998.0      5497
# 3            4                 Tal der Könige  1992.0      5497
# 4            5                        Acquire  1964.0      5497
# ...        ...                            ...     ...       ...
# 113899  391565                     Champions!  2023.0       NaN
# 113900  391715           Leitin að stjörnunni  2022.0       NaN
# 113901  391720  The String Railway Collection  2024.0       NaN
# 113902  391834                      SpellBook  2023.0       NaN
# 113903  392146            Nightmares of Sushi  2023.0       NaN
#
#                     designer       artist  \
# 0                          1   12517,4959
# 1                       8384        12424
# 2                          2        11883
# 3                       8008         2277
# 4                          4  12658,18317
# ...                      ...          ...
# 113899      62310,62311,6736          NaN
# 113900  154290,123339,154289          NaN
# 113901                 39436       113637
# 113902                  8347        45292
# 113903                 81537        81537
#
#                                                 publisher  min_players  \
# 0            133,2,24883,2726,15108,39249,11652,5382,8147          3.0
# 1                                                   64,20          3.0
# 2       17,133,267,29,7340,7335,41,2973,4617,1391,8291...          2.0
# 3                                                      37          2.0
# 4       92,5,4871,3082,858,2962,28072,5392,4668,38,462...          2.0
# ...                                                   ...          ...
# 113899                                          4384,1391          3.0
# 113900                                              54258          2.0
# 113901                                              44392          2.0
# 113902                                              25842          1.0
# 113903                                              52244          2.0
#
#         max_players  min_players_rec  ...  stddev_rating  bayes_rating  \
# 0               5.0              4.0  ...        1.57510       7.06367
# 1               4.0              3.0  ...        1.46752       5.76599
# 2               4.0              2.0  ...        1.19279       7.22869
# 3               4.0              2.0  ...        1.23667       5.66660
# 4               6.0              3.0  ...        1.33603       7.12541
# ...             ...              ...  ...            ...           ...
# 113899          8.0              3.0  ...            NaN           NaN
# 113900         20.0              2.0  ...            NaN           NaN
# 113901          5.0              2.0  ...            NaN           NaN
# 113902          4.0              1.0  ...            NaN           NaN
# 113903          6.0              2.0  ...            NaN           NaN
#
#         complexity  language_dependency  bga_id  dbpedia_id  luding_id  \
# 0           4.3144             1.166667     NaN         NaN        NaN
# 1           1.9636                  NaN     NaN         NaN        NaN
# 2           2.4784             1.006579     NaN         NaN        NaN
# 3           2.6667                  NaN     NaN         NaN        NaN
# 4           2.4985             1.095890     NaN         NaN        NaN
# ...            ...                  ...     ...         ...        ...
# 113899         NaN                  NaN     NaN         NaN        NaN
# 113900         NaN                  NaN     NaN         NaN        NaN
# 113901         NaN                  NaN     NaN         NaN        NaN
# 113902         NaN                  NaN     NaN         NaN        NaN
# 113903         NaN                  NaN     NaN         NaN        NaN
#
#        spielen_id wikidata_id  wikipedia_id
# 0             NaN         NaN           NaN
# 1             NaN         NaN           NaN
# 2             NaN         NaN           NaN
# 3             NaN         NaN           NaN
# 4             NaN         NaN           NaN
# ...           ...         ...           ...
# 113899        NaN         NaN           NaN
# 113900        NaN         NaN           NaN
# 113901        NaN         NaN           NaN
# 113902        NaN         NaN           NaN
# 113903        NaN         NaN           NaN
#
# [113904 rows x 38 columns]

# %%
# Selecting relevant collumn.

df1 = df["year"].astype('Int64').dropna(axis=0)

df1
# Out:
# 0         1986
# 1         1981
# 2         1998
# 3         1992
# 4         1964
#           ...
# 113899    2023
# 113900    2022
# 113901    2024
# 113902    2023
# 113903    2023
# Name: year, Length: 104219, dtype: Int64

# %%
df1.describe()
# Out:
# count       104219.0
# mean     2001.765551
# std        66.493704
# min          -3500.0
# 25%           1998.0
# 50%           2011.0
# 75%           2018.0
# max           2026.0
# Name: year, dtype: Float64

# %%
df1.unique()
# Out:
# <IntegerArray>
# [1986, 1981, 1998, 1992, 1964, 1989, 1978, 1993, 1997, 1999,
#  ...
#  1879, 1827, 1695, 1664, 2024, 1538, 1817, 2025, 2026, 1631]
# Length: 334, dtype: Int64

# %%
plt.figure(figsize=(12,5)) 

sns.histplot(data = df1)

plt.xticks(rotation=90);

# %%
df_sub1000 = df[df["year"] < 1000]

df_sub1000
# Out:
#         bgg_id                                      name    year  game_type  \
# 168        188                                        Go -2200.0       4666
# 1366      1602                      The Royal Game of Ur -2600.0       4666
# 1820      2136                                   Pachisi   400.0  4665,5499
# 2054      2393                                   Xiangqi   762.0       4666
# 2060      2399                                     Senet -3500.0       4666
# 2103      2448                                     Kalah   700.0       4666
# 2496      2912  Hounds and Jackals: Game of the Pharaohs -2000.0        NaN
# 2512      2932                                 Hnefatafl   400.0       4666
# 3361      3886                         Nine Men's Morris -1400.0       4666
# 3593      4148                                     Mehen -3000.0       4666
# 4717      5432                        Chutes and Ladders  -200.0       4665
# 4815      5546                                   Marbles -3000.0       4665
# 10284    11726                              Knucklebones -3000.0        NaN
# 10439    11901                               Tic-Tac-Toe -1300.0  4665,4666
# 10462    11929                                   Go-Moku   700.0       4666
# 11984    13654                                  Yut Nori   500.0       5498
# 12070    13761                                  Sugoroku   550.0       4666
# 12081    13776                                 Ashtapada  -350.0       4666
# 15785    18011                                Chaturanga   550.0       4666
# 17402    19915                        Three Men's Morris -1400.0       4666
# 18522    21264                           Byzantine Chess   900.0       4666
# 18705    21488                                   Petteia  -100.0       4666
# 19668    22610                                     Liubo  -700.0       4666
# 20170    23211                                20 Squares -3000.0        NaN
# 22356    25702                          Six Men's Morris -1400.0       4666
# 22673    26064                                  Shatranj   650.0       4666
# 24478    28128                                   Pah Tum -1800.0       4666
# 24630    28302                                     Oware   550.0       4666
# 25177    28931                                      Achi   300.0       4666
# 29294    33693                            Alea evangelii   800.0       4666
# 32784    37701                               Five Stones -2000.0        NaN
# 34409    39628                                    Jiroft -2600.0        NaN
# 35086    40412                                   Fan Tan  -600.0        NaN
# 35613    41247                                       Mia   600.0       5498
# 46487    96554                                    Tabula    41.0        NaN
# 47651   102420                                 T'shu-p'u   220.0        NaN
# 67882   180952                        Seven Men's Morris -1400.0        NaN
# 102229  340997                                Five Lines  -600.0        NaN
#
#        designer                                             artist  \
# 168           3                                        33954,70252
# 1366          3                                      109537,132798
# 1820          3  59100,9620,52372,54043,30281,6710,53833,141083...
# 2054          3                                                NaN
# 2060          3                            64922,128192,7628,79195
# 2103      98735                                              22153
# 2496          3                                               7628
# 2512          3                          132798,147223,10384,60765
# 3361          3                                109537,130246,60765
# 3593          3                                               7628
# 4717          3  52810,71033,8810,63030,10171,6710,141083,9988,...
# 4815          3                                                NaN
# 10284         3                                                NaN
# 10439         3                                                NaN
# 10462         3                                               4088
# 11984         3                                              48730
# 12070         3                                                NaN
# 12081         3                                                NaN
# 15785         3                                                NaN
# 17402         3                                                NaN
# 18522         3                                                NaN
# 18705     11064                                               9393
# 19668         3                                                NaN
# 20170         3                                                NaN
# 22356         3                                                NaN
# 22673         3                                                NaN
# 24478         3                                             130246
# 24630         3                                             109537
# 25177         3                                                NaN
# 29294         3                                                NaN
# 32784         3                                                NaN
# 34409         3                                                NaN
# 35086         3                                                NaN
# 35613         3                                                NaN
# 46487       NaN                                                NaN
# 47651       NaN                                                NaN
# 67882         3                                                  3
# 102229      NaN                                                NaN
#
#                                                 publisher  min_players  \
# 168     171,92,404,362,5,4922,4680,35302,6765,3828,130...          2.0
# 1366    171,22447,3251,3025,3115,24921,5085,6262,50685...          2.0
# 1820    171,9607,10814,7533,404,18931,16840,662,74,524...          2.0
# 2054    171,3320,46857,3828,1307,2401,11320,43675,2648...          2.0
# 2060    171,4,1017,553,7639,586,200,5085,384,24576,506...          2.0
# 2103    171,3320,1017,6514,404,74,4922,10992,30795,389...          2.0
# 2496                   171,3115,50685,15351,7938,5915,642          2.0
# 2512    171,1017,404,1997,74,35302,4109,27434,3115,511...          2.0
# 3361    171,4,1017,6514,1448,22447,73,10992,31495,1935...          2.0
# 3593        171,8756,3115,5085,50685,6266,5915,2432,45967          2.0
# 4717    171,20,1001,2008,1017,10814,30,690,4680,7548,2...          2.0
# 4815        171,225,5314,1195,50975,635,93,782,29995,1722          1.0
# 10284                        171,3320,5314,5722,6720,7063          2.0
# 10439   171,3320,1017,6514,33079,225,5314,2401,18726,1...          2.0
# 10462   171,1017,404,1997,74,586,45548,17151,63,45541,...          2.0
# 11984   171,3320,1840,22447,3115,50793,16750,5085,1715...          2.0
# 12070                                           171,10759          2.0
# 12081                                            171,3115          2.0
# 15785               171,1017,2492,1270,752,5085,24407,254          2.0
# 17402                                            171,6261          2.0
# 18522                                       171,5085,7458          2.0
# 18705   171,3115,5085,53512,50685,6266,10094,49182,182...          2.0
# 19668                                                 171          2.0
# 20170                                           171,50685          2.0
# 22356                                              171,20          2.0
# 22673                                                 171          2.0
# 24478                                           171,50098          2.0
# 24630   171,22447,3082,17151,39371,6266,15351,24407,62...          2.0
# 25177                           171,38726,6432,6266,49182          2.0
# 29294                                      171,5085,53614          2.0
# 32784                                            171,5314          1.0
# 34409                                                 171          NaN
# 35086                                                 171          3.0
# 35613                                       171,18021,254          2.0
# 46487                                     171,50685,24407          2.0
# 47651                                               171,4          4.0
# 67882                                                 171          2.0
# 102229                                              49182          2.0
#
#         max_players  min_players_rec  ...  stddev_rating  bayes_rating  \
# 168             2.0              2.0  ...        1.90884       7.31279
# 1366            2.0              2.0  ...        1.77279       5.62353
# 1820            6.0              2.0  ...        1.88432       4.69962
# 2054            2.0              2.0  ...        1.56620       6.25621
# 2060            2.0              2.0  ...        1.66428       5.56898
# 2103            2.0              2.0  ...        1.43692       5.80870
# 2496            2.0              2.0  ...        2.18944           NaN
# 2512            2.0              2.0  ...        1.46582       5.96272
# 3361            2.0              2.0  ...        1.61864       5.40718
# 3593            6.0              2.0  ...        1.98437           NaN
# 4717            6.0              2.0  ...        1.66474       3.64057
# 4815           99.0              1.0  ...        1.70749       5.33775
# 10284           2.0              2.0  ...        1.34084       5.50534
# 10439           2.0              2.0  ...        1.99005       3.62489
# 10462           2.0              2.0  ...        1.66848       5.60544
# 11984           8.0              2.0  ...        1.64877       5.51083
# 12070           2.0              2.0  ...            NaN           NaN
# 12081           2.0              2.0  ...        2.50000           NaN
# 15785           4.0              2.0  ...        1.46089       5.51860
# 17402           2.0              2.0  ...        1.90941       5.45918
# 18522           2.0              2.0  ...        1.60395           NaN
# 18705           2.0              2.0  ...        1.59649       5.51434
# 19668           2.0              2.0  ...        1.00000           NaN
# 20170           2.0              2.0  ...            NaN           NaN
# 22356           2.0              2.0  ...        1.45985           NaN
# 22673           2.0              2.0  ...        1.75000           NaN
# 24478           2.0              2.0  ...        1.70692           NaN
# 24630           2.0              2.0  ...        1.55713       5.66518
# 25177           2.0              2.0  ...        1.95492           NaN
# 29294           2.0              2.0  ...        2.55473           NaN
# 32784           4.0              1.0  ...        1.68422           NaN
# 34409           NaN              NaN  ...            NaN           NaN
# 35086           8.0              3.0  ...            NaN           NaN
# 35613          12.0              2.0  ...        1.87739       5.53424
# 46487           2.0              2.0  ...        1.51984           NaN
# 47651           4.0              4.0  ...        3.03109           NaN
# 67882           2.0              2.0  ...            NaN           NaN
# 102229          2.0              2.0  ...            NaN           NaN
#
#         complexity  language_dependency  bga_id  dbpedia_id  luding_id  \
# 168         3.9338             1.010753     NaN         NaN        NaN
# 1366        1.2857                  NaN     NaN         NaN        NaN
# 1820        1.1931             1.020833     NaN         NaN        NaN
# 2054        3.5670                  NaN     NaN         NaN        NaN
# 2060           NaN                  NaN     NaN         NaN        NaN
# 2103        1.6040             1.041667     NaN         NaN        NaN
# 2496        1.0000                  NaN     NaN         NaN        NaN
# 2512        2.5000                  NaN     NaN         NaN        NaN
# 3361        1.8231                  NaN     NaN         NaN        NaN
# 3593        1.0000                  NaN     NaN         NaN        NaN
# 4717        1.0305             1.000000     NaN         NaN        NaN
# 4815        1.1000                  NaN     NaN         NaN        NaN
# 10284       1.0000                  NaN     NaN         NaN        NaN
# 10439       1.2874             1.016667     NaN         NaN        NaN
# 10462       1.8387                  NaN     NaN         NaN        NaN
# 11984       1.3333                  NaN     NaN         NaN        NaN
# 12070          NaN                  NaN     NaN         NaN        NaN
# 12081          NaN                  NaN     NaN         NaN        NaN
# 15785       2.2500                  NaN     NaN         NaN        NaN
# 17402       1.2222                  NaN     NaN         NaN        NaN
# 18522       3.0000                  NaN     NaN         NaN        NaN
# 18705       2.1667                  NaN     NaN         NaN        NaN
# 19668          NaN                  NaN     NaN         NaN        NaN
# 20170          NaN                  NaN     NaN         NaN        NaN
# 22356       2.0000                  NaN     NaN         NaN        NaN
# 22673       4.0000                  NaN     NaN         NaN        NaN
# 24478       1.5000                  NaN     NaN         NaN        NaN
# 24630       2.0833                  NaN     NaN         NaN        NaN
# 25177       1.2500                  NaN     NaN         NaN        NaN
# 29294       3.0000                  NaN     NaN         NaN        NaN
# 32784       1.0000                  NaN     NaN         NaN        NaN
# 34409          NaN                  NaN     NaN         NaN        NaN
# 35086          NaN                  NaN     NaN         NaN        NaN
# 35613       1.1429                  NaN     NaN         NaN        NaN
# 46487       1.5000                  NaN     NaN         NaN        NaN
# 47651          NaN                  NaN     NaN         NaN        NaN
# 67882          NaN                  NaN     NaN         NaN        NaN
# 102229         NaN                  NaN     NaN         NaN        NaN
#
#        spielen_id wikidata_id  wikipedia_id
# 168           NaN         NaN           NaN
# 1366          NaN         NaN           NaN
# 1820          NaN         NaN           NaN
# 2054          NaN         NaN           NaN
# 2060          NaN         NaN           NaN
# 2103          NaN         NaN           NaN
# 2496          NaN         NaN           NaN
# 2512          NaN         NaN           NaN
# 3361          NaN         NaN           NaN
# 3593          NaN         NaN           NaN
# 4717          NaN         NaN           NaN
# 4815          NaN         NaN           NaN
# 10284         NaN         NaN           NaN
# 10439         NaN         NaN           NaN
# 10462         NaN         NaN           NaN
# 11984         NaN         NaN           NaN
# 12070         NaN         NaN           NaN
# 12081         NaN         NaN           NaN
# 15785         NaN         NaN           NaN
# 17402         NaN         NaN           NaN
# 18522         NaN         NaN           NaN
# 18705         NaN         NaN           NaN
# 19668         NaN         NaN           NaN
# 20170         NaN         NaN           NaN
# 22356         NaN         NaN           NaN
# 22673         NaN         NaN           NaN
# 24478         NaN         NaN           NaN
# 24630         NaN         NaN           NaN
# 25177         NaN         NaN           NaN
# 29294         NaN         NaN           NaN
# 32784         NaN         NaN           NaN
# 34409         NaN         NaN           NaN
# 35086         NaN         NaN           NaN
# 35613         NaN         NaN           NaN
# 46487         NaN         NaN           NaN
# 47651         NaN         NaN           NaN
# 67882         NaN         NaN           NaN
# 102229        NaN         NaN           NaN
#
# [38 rows x 38 columns]

# %%
df_sub1000.min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 1
# ----> 1 df_sub1000.min()
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:11643, in DataFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   11635 @doc(make_doc("min", ndim=2))
#   11636 def min(
#   11637     self,
#    (...)
#   11641     **kwargs,
#   11642 ):
# > 11643     result = super().min(axis, skipna, numeric_only, **kwargs)
#   11644     if isinstance(result, Series):
#   11645         result = result.__finalize__(self, method="min")
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py:12388, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12381 def min(
#   12382     self,
#   12383     axis: Axis | None = 0,
#    (...)
#   12386     **kwargs,
#   12387 ):
# > 12388     return self._stat_function(
#   12389         "min",
#   12390         nanops.nanmin,
#   12391         axis,
#   12392         skipna,
#   12393         numeric_only,
#   12394         **kwargs,
#   12395     )
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py:12377, in NDFrame._stat_function(self, name, func, axis, skipna, numeric_only, **kwargs)
#   12373 nv.validate_func(name, (), kwargs)
#   12375 validate_bool_kwarg(skipna, "skipna", none_allowed=False)
# > 12377 return self._reduce(
#   12378     func, name=name, axis=axis, skipna=skipna, numeric_only=numeric_only
#   12379 )
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:11562, in DataFrame._reduce(self, op, name, axis, skipna, numeric_only, filter_type, **kwds)
#   11558     df = df.T
#   11560 # After possibly _get_data and transposing, we are now in the
#   11561 #  simple case where we can use BlockManager.reduce
# > 11562 res = df._mgr.reduce(blk_func)
#   11563 out = df._constructor_from_mgr(res, axes=res.axes).iloc[0]
#   11564 if out_dtype is not None and out.dtype != "boolean":
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/internals/managers.py:1500, in BlockManager.reduce(self, func)
#    1498 res_blocks: list[Block] = []
#    1499 for blk in self.blocks:
# -> 1500     nbs = blk.reduce(func)
#    1501     res_blocks.extend(nbs)
#    1503 index = Index([None])  # placeholder
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/internals/blocks.py:404, in Block.reduce(self, func)
#     398 @final
#     399 def reduce(self, func) -> list[Block]:
#     400     # We will apply the function and reshape the result into a single-row
#     401     #  Block with the same mgr_locs; squeezing will be done at a higher level
#     402     assert self.ndim == 2
# --> 404     result = func(self.values)
#     406     if self.values.ndim == 1:
#     407         res_values = result
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/frame.py:11481, in DataFrame._reduce.<locals>.blk_func(values, axis)
#   11479         return np.array([result])
#   11480 else:
# > 11481     return op(values, axis=axis, skipna=skipna, **kwds)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/nanops.py:147, in bottleneck_switch.__call__.<locals>.f(values, axis, skipna, **kwds)
#     145         result = alt(values, axis=axis, skipna=skipna, **kwds)
#     146 else:
# --> 147     result = alt(values, axis=axis, skipna=skipna, **kwds)
#     149 return result
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/nanops.py:404, in _datetimelike_compat.<locals>.new_func(values, axis, skipna, mask, **kwargs)
#     401 if datetimelike and mask is None:
#     402     mask = isna(values)
# --> 404 result = func(values, axis=axis, skipna=skipna, mask=mask, **kwargs)
#     406 if datetimelike:
#     407     result = _wrap_results(result, orig_values.dtype, fill_value=iNaT)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/nanops.py:1098, in _nanminmax.<locals>.reduction(values, axis, skipna, mask)
#    1093     return _na_for_min_count(values, axis)
#    1095 values, mask = _get_values(
#    1096     values, skipna, fill_value_typ=fill_value_typ, mask=mask
#    1097 )
# -> 1098 result = getattr(values, meth)(axis)
#    1099 result = _maybe_null_out(result, axis, mask, values.shape)
#    1100 return result
#
# File /opt/miniconda3/lib/python3.12/site-packages/numpy/_core/_methods.py:49, in _amin(a, axis, out, keepdims, initial, where)
#      47 def _amin(a, axis=None, out=None, keepdims=False,
#      48           initial=_NoValue, where=True):
# ---> 49     return umr_minimum(a, axis, None, out, keepdims, initial, where)
#
# TypeError: '<=' not supported between instances of 'str' and 'float'

# %%
df2 = df1[df1 > 1900]

df2
# Out:
# 0         1986
# 1         1981
# 2         1998
# 3         1992
# 4         1964
#           ...
# 113899    2023
# 113900    2022
# 113901    2024
# 113902    2023
# 113903    2023
# Name: year, Length: 103109, dtype: Int64

# %%
plt.figure(figsize=(12,5)) 

sns.histplot(data = df2)

plt.xticks(rotation=90);
