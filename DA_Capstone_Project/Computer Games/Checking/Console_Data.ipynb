# %%
# List of consoles released since 1976.

# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/Console_Data.csv")

df
# Out:
#                      Console Name  Type    Company      Gen     Gen Years  \
# 0                Magnavox Odyssey  Home   Magnavox  1st Gen     1972-1978
# 1                       Home Pong  Home      Atari  1st Gen     1972-1978
# 2                      Atari 2600  Home      Atari  2nd Gen     1978-1982
# 3              Magnavox Odyssey 2  Home   Magnavox  2nd Gen     1978-1982
# 4                   Intellivision  Home     Mattel  2nd Gen     1978-1982
# 5                 Atari 5200/7800  Home      Atari  3rd Gen     1982-1988
# 6   Nintendo Entertainment System  Home   Nintendo  3rd Gen     1982-1988
# 7              Sega Master System  Home       Sega  3rd Gen     1982-1988
# 8                    Sega Genesis  Home       Sega  4th Gen     1988-1994
# 9                  Super Nintendo  Home   Nintendo  4th Gen     1988-1994
# 10                    PlayStation  Home       Sony  5th Gen     1994-1998
# 11                    Sega Saturn  Home       Sega  5th Gen     1994-1998
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 26 entries, 0 to 25
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Console Name          26 non-null     object
#  1   Type                  26 non-null     object
#  2   Company               26 non-null     object
#  3   Gen                   26 non-null     object
#  4   Gen Years             26 non-null     object
#  5   Released Year         26 non-null     int64
#  6   Generation            26 non-null     int64
#  7   Discontinuation Year  26 non-null     object
#  8   Units sold (million)  26 non-null     float64
#  9   Remarks               26 non-null     object
#  10  Link to gif           26 non-null     object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 2.4+ KB

# %%
df.describe()
# Out:
#        Released Year  Generation  Units sold (million)
# count      26.000000   26.000000             26.000000
# mean     1996.384615    5.230769             47.326923
# std        14.612534    2.550415             45.542229
# min      1972.000000    1.000000              0.150000
# 25%      1983.750000    3.000000             10.000000
# 50%      1997.000000    5.500000             31.500000
# 75%      2006.000000    7.000000             78.500000
# max      2020.000000    9.000000            155.000000

# %%
df["Type"].unique()
# Out:
# array(['Home'], dtype=object)

# %%
df["Company"].unique()
# Out:
# array(['Magnavox', 'Atari', 'Mattel', 'Nintendo', 'Sega', 'Sony',
#        'Microsoft'], dtype=object)
