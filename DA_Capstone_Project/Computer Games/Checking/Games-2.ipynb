# %%
# Review scores across multiple platforms.

# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/Games-2.csv")

df
# Out:
#              Console                                           GameName  \
# 0                 PC                Baldur's Gate 3 Early Access Review
# 1                 NS     Control: Ultimate Edition Cloud Version Review
# 2      XONE, PC, PS4       Doom Eternal: The Ancient Gods Part 1 Review
# 3      XONE, PC, PS4                          Watch Dogs: Legion Review
# 4                 PC                                Ring Of Pain Review
# ...              ...                                                ...
# 14796             PC                                     Doom II Review
# 14797             PC  Dungeon Master II: The Legend of Skullkeep Review
# 14798             PC                                    Endorfun Review
# 14799             PC                              FIFA Soccer 96 Review
# 14800             PC                               Full Throttle Review
#
#              Review  Score
# 0      Early Access      6
# 1              Good      7
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14801 entries, 0 to 14800
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Console   14801 non-null  object
#  1   GameName  14801 non-null  object
#  2   Review    14801 non-null  object
#  3   Score     14801 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 462.7+ KB

# %%
df.describe()
# Out:
#               Score
# count  14801.000000
# mean       6.429498
# std        1.611753
# min        1.000000
# 25%        6.000000
# 50%        7.000000
# 75%        8.000000
# max        9.000000

# %%
df["Console"].unique()
# Out:
# array(['PC', 'NS', 'XONE, PC, PS4', 'PC, XONE, PS4', 'PC, NS',
#        'XONE, PS4', 'PC, PS4', 'PC, XONE, PS4, NS', 'NS, NS', 'PS4',
#        'PC, PS4, XONE, NS', 'XONE, PC', 'PS4, XONE', 'PC, PS4, NS',
#        'PS4, PC, XONE', 'IOS', 'PC, XONE', 'PC, IOS', 'XONE',
#        'PC, XONE, NS', 'PC, PS4, NS, XONE', 'WIIU', 'PC, PS4, XONE',
#        'PC, NS, XONE, PS4', 'LNX, MAC, AND, PC', 'PC, NS, IOS',
#        'PS4, XONE, PC', 'PS4, PS4', 'AND, IOS', 'PC, PS4, PS4',
#        'IOS, PC, NS', 'NS, PS4', 'PS4, PC', 'NS, PC', '3DS',
#        'XONE, PC, NS', 'PS4, XONE, NS, PC', 'PS4, PC, XONE, NS',
#        'XONE, NS', 'PC, MAC', 'NS, XONE, PS4', 'PS4, XONE, PC, NS',
#        'XONE, PS3, NS', 'XONE, PS4, NS', 'PC, MAC, PS4, NS', 'TG16',
#        'PS3, VITA, PS4', 'NS, PS4, XONE, PC', 'PS4, NS, XONE, PC',
#        'XONE, PS4, PC', 'XONE, NS, PC, PS4', 'PS4, NS', 'PC, PS3, X360',
#        'WIIU, NS', 'PS4, PC, NS', 'PS4, VITA', '3DS, 3DS',
# ...
