# %%
# Limited list of game released since 2001.

# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/Games-3.csv")

df
# Out:
#                                      Name  Sales          Series Release  \
# 0           PlayerUnknown's Battlegrounds   42.0             NaN  Dec-17
# 1                               Minecraft   33.0       Minecraft  Nov-11
# 2                              Diablo III   20.0          Diablo  May-12
# 3                             Garry's Mod   20.0             NaN  Nov-06
# 4                                Terraria   17.2             NaN  May-11
# ..                                    ...    ...             ...     ...
# 170                              Vietcong    1.0        Vietcong  Mar-03
# 171    Warhammer Online: Age of Reckoning    1.0       Warhammer  Sep-08
# 172        Who Wants to Be a Millionaire?    1.0             NaN  Nov-99
# 173  Wing Commander 3: Heart of the Tiger    1.0  Wing Commander  Dec-94
# 174                            Zoo Tycoon    1.0      Zoo Tycoon  Oct-01
#
#                        Genre               Developer  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 175 entries, 0 to 174
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Name       175 non-null    object
#  1   Sales      175 non-null    float64
#  2   Series     139 non-null    object
#  3   Release    175 non-null    object
#  4   Genre      175 non-null    object
#  5   Developer  175 non-null    object
#  6   Publisher  175 non-null    object
# dtypes: float64(1), object(6)
# memory usage: 9.7+ KB

# %%
df.describe()
# Out:
#             Sales
# count  175.000000
# mean     3.141143
# std      4.960513
# min      1.000000
# 25%      1.000000
# 50%      1.500000
# 75%      3.000000
# max     42.000000

# %%
df["Genre"].unique()
# Out:
# array(['Battle royale', 'Sandbox,\xa0survival', 'Action role-playing',
#        'Sandbox', 'Action-adventure', 'MMORPG', 'First-person shooter',
#        'Real-time strategy', 'Life simulation',
#        'Construction and management simulation', 'Survival',
#        'Turn-based strategy,\xa04X', 'Vehicle simulation',
#        'Tactical shooter', 'City-building', 'God game', 'Educational',
#        'Graphic adventure', 'City-building game', 'Turn-based strategy',
#        'Adventure,\xa0puzzle', 'Role-playing game', 'Survival horror',
#        'Computer role-playing game', 'Third-person shooter',
#        'Racing game', 'Simulation', 'Fighting',
#        'Action-adventure,\xa0roguelike', 'Action-adventure,\xa0stealth',
#        'Compilation', 'RTS,\xa04X,\xa0Grand Strategy',
#        'Third-person shooter,\xa0survival horror',
#        'Action role-playing,\xa0hack and slash',
#        'Action role-playing game', 'Maze,\xa0arcade',
# ...

# %%
df["Release"].min()
# Out:
# 'Apr-01'
