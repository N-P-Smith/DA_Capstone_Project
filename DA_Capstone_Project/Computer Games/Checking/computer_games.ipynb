# %%
# List of games released on PC and Mac since 1986.
# Does not appear comprehensive.

# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/computer_games.csv")

df
# Out:
#                                     Name                        Developer  \
# 0                                A-Men 2                     Bloober Team
# 1                                A-Train                          Artdink
# 2                             A-10 Cuba!              Parsoft Interactive
# 3                              A.D. 2044                  R.M.P. Software
# 4     A.D.A.M. Life's Greatest Mysteries  Columbia Healthcare Corporation
# ...                                  ...                              ...
# 1090                688(I) Hunter/Killer                   Sonalysts Inc.
# 1091                            7 Colors                       Gamos Ltd.
# 1092                                7554                      Emobi Games
# 1093                          7th Legion           Vision, Epic MegaGames
# 1094                  9: The Last Resort              Tribeca Interactive
#
#                              Producer                    Genre  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1095 entries, 0 to 1094
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Name              1095 non-null   object
#  1   Developer         1095 non-null   object
#  2   Producer          1095 non-null   object
#  3   Genre             1095 non-null   object
#  4   Operating System  1095 non-null   object
#  5   Date Released     1095 non-null   object
# dtypes: object(6)
# memory usage: 51.5+ KB

# %%
df.describe()
# Out:
#                  Name Developer         Producer                 Genre  \
# count            1095      1095             1095                  1095
# unique           1094       583              489                   282
# top     A Hat in Time     Maxis  Electronic Arts  First-person shooter
# freq                2        30               84                   103
#
#          Operating System Date Released
# count                1095          1095
# unique                 83           915
# top     Microsoft Windows          1995
# freq                  600             9

# %%
df["Developer"].unique()
# Out:
# array(['Bloober Team', 'Artdink', 'Parsoft Interactive',
#        'R.M.P. Software', 'Columbia Healthcare Corporation',
#        'Extend Studio', 'Stanislaw Truchowskit', 'Gears for Breakfast',
#        'Cyanide', 'Corbis Corporation', 'ImageBuilder Software',
#        'Dejobaan Games', 'Mad Fellows', 'Shot Sports Software',
#        'OT Sports]', 'Hothouse Creations', 'Funselektor Labs',
#        'TQ Digital', 'Sloclap', 'ACE Team', 'Giant Squid Studios',
#        'Orange Juice', 'Crows Crows Crows', 'Bandai Namco Studios',
#        'Project Aces', 'Absolute Studios', 'Jagex', 'MasangSoft Inc.',
#        '7th Level', 'HiTech Creations', 'Artech Digital Entertainment',
#        'Dynamix', 'Hazardous Software, Inc.', 'Graviteam',
#        'Big Time Software', 'Andrea Jennifer Shubert', 'Eugen Systems',
#        'The A-Team', 'MumboJumbo, MacPlay', 'Gremlin Interactive',
#        'Nick Montfort', 'Strategic Simulations',
# ...

# %%
df["Producer"].unique()
# Out:
# array(['Bloober Team', 'Artdink, Maxis, Ocean Software', 'Activision',
#        'LK Avalon', 'Columbia Healthcare Corporation',
#        'Origo Games, Aksys Games', 'TurnVex', 'Gears for Breakfast',
#        'Focus Home Interactive', 'Corbis Corporation',
#        'ImageBuilder Software', 'Dejobaan Games', 'Mad Fellows',
#        'ABC Interactive', 'Eidos Interactive', 'Funselektor Labs',
#        'NetDragon Websoft Inc.', 'Devolver Digital', 'Atlus', '505 Games',
#        'Bandai Namco Entertainment', "Rockin' Android",
#        'Crows Crows Crows', 'Namco Bandai Games', 'Gamezlab', 'Jagex',
#        'Many', 'Bomico Entertainment Software', 'HiTech Creations',
#        'Vivendi Games', 'Sierra Entertainment',
#        'Hazardous Software, Inc.', 'Paradox Interactive', 'Avalon Hill',
#        'Internet Relay Chat', 'Atari, Inc.', 'The A-Team',
#        'Fox Sports Interactive', 'Gremlin Interactive',
#        'Greenwood Entertainment', 'Nick Montfort',
# ...

# %%
df["Genre"].unique()
# Out:
# array(['Adventure, Puzzle', 'Vehicle Simulation Game', 'Flight simulator',
#        'Adventure', 'Educational', 'Action, platform',
#        'Platform, action-adventure', 'Strategy', 'Fine Art', 'Simulation',
#        'Action, Rhythm/Music', 'Racing', 'Sports',
#        'Action, real-time tactics', 'Racing game',
#        'First-person shooter, third-person shooter',
#        'Action role-playing', 'Roguelike, action-adventure',
#        'Adventure, art game, simulation', 'Fighting', 'Exploration game',
#        'Combat flight simulator',
#        'Action-adventure, third-person shooter, platform game',
#        'First-person shooter', 'MMO, 3D Space Shooter',
#        'Graphic Adventure (Point-and-click)', 'Rail shooter',
#        'Real-time strategy', 'Real-time strategy, Wargame',
#        'Strategy, Computer wargaming', 'Word', 'Real-time Strategy (RTS)',
#        'Compilation', 'Soccer', 'Text Adventure, Interactive Fiction',
#        'Role-playing video game', 'Pinball',
# ...

# %%
df["Operating System"].unique()
# Out:
# array(['Microsoft Windows', 'Windows, Mac', 'macOS, Microsoft Windows',
#        'Microsoft Windows, macOS', 'IBM PC', 'MS-DOS',
#        'BeOS, Linux, Mac OS, Microsoft Windows',
#        'Microsoft Windows, Macintosh', 'Microsoft Windows, Linux, macOS',
#        'Windows, macOS', 'Apple II, Atari 8-bit, Commodore 64',
#        'Microsoft Windows,', 'Microsoft Windows, Classic Mac OS',
#        'Microsoft Windows, Linux', 'MS-DOS, Amiga, Atari ST',
#        'Apple II, Commodore 64, MS-DOS', 'MS-DOS, Microsoft Windows',
#        'Microsoft Windows, macOS, Linux', 'Microsoft Windows, OS X',
#        'Microsoft Windows, Mac OS X', 'Windows 10 64-Bit, Mac OS X',
#        'MS-DOS, Apple II, Commodore 64, Amiga',
#        'Microsoft Windows Mac OS X',
#        'MS-DOS, Apple II, macOS, Commodore 64, Amiga, Atari ST, NEC PC-9801',
#        'MS-DOS, Commodore 64, Amiga', 'MS-DOS, Linux',
#        'MS-DOS, Macintosh',
# ...

# %%
df["Date Released"].min()
# Out:
# '1983'

# %%
df["Date Released"].max()
# Out:
# 'TBA'
