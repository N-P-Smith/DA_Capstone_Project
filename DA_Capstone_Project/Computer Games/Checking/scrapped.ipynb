# %%
# List of conlsole games.

# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/scrapped_data.csv")

df
# Out:
#                                        Game Name System Full  Units(m)  \
# 0                                        Pac-Man  Atari 2600      7.70
# 1                                       Pitfall!  Atari 2600      4.00
# 2                                        Frogger  Atari 2600      4.00
# 3                                Missile Command  Atari 2600      2.50
# 4                                 Space Invaders  Atari 2600      2.00
# ...                                          ...         ...       ...
# 27303                          Fishing Sim World    Xbox One      0.05
# 27304                                The Council    Xbox One      0.00
# 27305                                      Sable    Xbox One      0.00
# 27306  Doom Eternal: The Ancient Gods - Part Two    Xbox One      0.00
# 27307                           VISCO Collection    Xbox One      0.00
#
#                 Publisher           Developer  \
# 0                   Atari               Atari
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27308 entries, 0 to 27307
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Game Name     27308 non-null  object
#  1   System Full   27308 non-null  object
#  2   Units(m)      27308 non-null  float64
#  3   Publisher     27308 non-null  object
#  4   Developer     27305 non-null  object
#  5   Image_URL     27308 non-null  object
#  6   Release Date  24333 non-null  object
# dtypes: float64(1), object(6)
# memory usage: 1.5+ MB

# %%
df.describe()
# Out:
#           Units(m)
# count  27308.00000
# mean       0.29597
# std        1.36360
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.16000
# max       82.90000

# %%
df["System Full"].unique()
# Out:
# array(['Atari 2600', 'Atari 5200/7800', 'GameCube', 'Intellivision',
#        'Nintendo 64', 'Nintendo Entertainment System', 'Nintendo Switch',
#        'PlayStation', 'PlayStation 2', 'PlayStation 3', 'PlayStation 4',
#        'Sega Dreamcast', 'Sega Genesis', 'Sega Master System',
#        'Sega Saturn', 'Super Nintendo', 'Wii', 'Wii U', 'Xbox',
#        'Xbox 360', 'Xbox One'], dtype=object)

# %%
df["Release Date"].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 df["Release Date"].min()
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/series.py:6507, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6499 @doc(make_doc("min", ndim=1))
#    6500 def min(
#    6501     self,
#    (...)
#    6505     **kwargs,
#    6506 ):
# -> 6507     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py:12388, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12381 def min(
#   12382     self,
#   12383     axis: Axis | None = 0,
#    (...)
#   12386     **kwargs,
#   12387 ):
# > 12388     return self._stat_function(
#   12389         "min",
#   12390         nanops.nanmin,
#   12391         axis,
#   12392         skipna,
# ...
