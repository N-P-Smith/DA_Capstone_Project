# %%
# Good list of games released on Steam.

# %%
import pandas as pd

# %%
df = pd.read_csv("../Data/steam-games.csv")

df
# Out:
#         app_id                                              title  \
# 0          730                                   Counter-Strike 2
# 1          570                                             Dota 2
# 2      2215430                   Ghost of Tsushima DIRECTOR'S CUT
# 3      1245620                                         ELDEN RING
# 4      1085660                                          Destiny 2
# ...        ...                                                ...
# 42492   477910                               Wanderer of Teandria
# 42493  1501390                                          KING PONG
# 42494  2683250                              Falnarion Tactics III
# 42495  1508840  Great Exploration VR: New Colony beyond Viking...
# 42496  1191080                                           SANCTION
#
#        release_date                                             genres  \
# 0      21 Aug, 2012                               Action, Free to Play
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42497 entries, 0 to 42496
# Data columns (total 24 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   app_id                42497 non-null  int64
#  1   title                 42497 non-null  object
#  2   release_date          42440 non-null  object
#  3   genres                42410 non-null  object
#  4   categories            42452 non-null  object
#  5   developer             42307 non-null  object
#  6   publisher             42286 non-null  object
#  7   original_price        4859 non-null   object
#  8   discount_percentage   4859 non-null   object
#  9   discounted_price      42257 non-null  object
#  10  dlc_available         42497 non-null  int64
#  11  age_rating            42497 non-null  int64
#  12  content_descriptor    2375 non-null   object
#  13  about_description     42359 non-null  object
#  14  win_support           42497 non-null  bool
# ...

# %%
df.describe()
# Out:
#              app_id  dlc_available    age_rating        awards  \
# count  4.249700e+04   42497.000000  42497.000000  42497.000000
# mean   1.245812e+06       0.722004      0.055886      0.309528
# std    7.553906e+05       4.673810      0.229705      1.264100
# min    1.000000e+01       0.000000      0.000000      0.000000
# 25%    5.892200e+05       0.000000      0.000000      0.000000
# 50%    1.144860e+06       0.000000      0.000000      0.000000
# 75%    1.822640e+06       0.000000      0.000000      0.000000
# max    3.008050e+06     200.000000      1.000000     41.000000
#
#        overall_review_%  overall_review_count  recent_review_%  \
# count      40020.000000          4.002000e+04      5503.000000
# mean          77.162569          2.500621e+03        82.303107
# std           17.672036          4.887980e+04        15.110260
# min            0.000000          1.000000e+01         6.000000
# 25%           68.000000          2.100000e+01        75.000000
# ...

# %%
df["genres"].unique()
# Out:
# array(['Action, Free to Play', 'Action, Strategy, Free to Play',
#        'Action, Adventure', ...,
#        'Action, Adventure, Casual, Racing, RPG, Simulation',
#        'Action, Adventure, Sports, Early Access',
#        'Massively Multiplayer, Racing, Early Access'], dtype=object)

# %%
df["categories"].unique()
# Out:
# array(['Cross-Platform Multiplayer, Steam Trading Cards, Steam Workshop, In-App Purchases, Valve Anti-Cheat enabled, Stats, Remote Play on Phone, Remote Play on Tablet, Remote Play on TV',
#        'Steam Trading Cards, Steam Workshop, SteamVR Collectibles, In-App Purchases, Valve Anti-Cheat enabled',
#        'Single-player, Online Co-op, Steam Achievements, Family Sharing',
#        ...,
#        'Single-player, Shared/Split Screen PvP, Shared/Split Screen Co-op, Steam Achievements, Steam Cloud, Steam Leaderboards, Remote Play on Phone, Remote Play Together, Family Sharing, Profile Features Limited',
#        'Single-player, Online PvP, Cross-Platform Multiplayer, Steam Workshop, Includes level editor, Family Sharing',
#        'Single-player, Online PvP, Steam Achievements, Tracked Controller Support, VR Supported, Family Sharing'],
#       dtype=object)

# %%
df["release_date"].min()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 df["release_date"].min()
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/series.py:6507, in Series.min(self, axis, skipna, numeric_only, **kwargs)
#    6499 @doc(make_doc("min", ndim=1))
#    6500 def min(
#    6501     self,
#    (...)
#    6505     **kwargs,
#    6506 ):
# -> 6507     return NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#
# File /opt/miniconda3/lib/python3.12/site-packages/pandas/core/generic.py:12388, in NDFrame.min(self, axis, skipna, numeric_only, **kwargs)
#   12381 def min(
#   12382     self,
#   12383     axis: Axis | None = 0,
#    (...)
#   12386     **kwargs,
#   12387 ):
# > 12388     return self._stat_function(
#   12389         "min",
#   12390         nanops.nanmin,
#   12391         axis,
#   12392         skipna,
# ...
